# %%
import pandas as pd
import numpy as np

df = pd.read_csv('final.csv',encoding="ISO-8859-1")
df
# Out:
#       Unnamed: 0                    BCI  \
# 0              0        Public Document
# 1              1        Public Document
# 2              2  Public Version of BCI
# 3              3        Public Document
# 4              4  Public Version of BCI
# ...          ...                    ...
# 16247      10842                    NaN
# 16248      10843                    NaN
# 16249      10844                    NaN
# 16250      10845                    NaN
# 16251      10846                    NaN
#
#                                        Prod Name/Descrip HTS 10 Digit  \
# 0      this exclusion request is for product number s...   8459704000
# 1      this exclusion request is for part # 19-00-132...   8482400000
# 2      the product is a lever arm assembly sold to fo...   8414904190
# 3      the exclusion request is for product number 68...   8544300000
# 4      electric motors ranging from 152 kilowatts (__...   8501538040
# ...

# %%
df = df[['filename','2017 Value',
 '2016 Value',
 '2015 Value',
 '2017 Quant',
 '2016 Quant',
 '2015 Quant']]
df = df.iloc[100:300,1000:1200]

# %%
df.to_csv('trie1.csv')

# %%
# Out:
# {'encoding': 'utf-8', 'confidence': 0.99, 'language': ''}

# %%
# Out:
#   File "<ipython-input-7-05ef5eba3011>", line 2
#     with codecs.open('final.csv', 'r', encoding='utf-8',errors='ignore') as fdata:
#                                                                                   ^
# SyntaxError: unexpected EOF while parsing
